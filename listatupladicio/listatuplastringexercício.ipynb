# %% [markdown]
# <a href="https://colab.research.google.com/github/juliaaparecida120/PA_2025/blob/main/listatupladicio/listatuplastringexerc%C3%ADcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercícios de listas de tuplas**

# %%
cidade = ["Xique-xique", "Rio Grande da Serra", "Santa Catarina", "Mauá", "São Vicente"]
cidade.append("Anta Gorda")
cidade.pop(1)
print(cidade)
# Out:
# ['Xique-xique', 'Santa Catarina', 'Mauá', 'São Vicente', 'Anta Gorda']

# %%
tupla1 = ("roxo", "verde", "amarelo", "preto")
novas_cores = tupla1 + ("vermelho",)
print(novas_cores)
# Out:
# ('roxo', 'verde', 'amarelo', 'preto', 'vermelho')

# %%
dicionario = {
  "nome": "xica",
  "idade": 28,
  "curso": "direito",

}
print(dicionario)
# Out:
# {'nome': 'xica', 'idade': 28, 'curso': 'direito'}

# %%
dicionario1 = {
  "produto": "leite em pó",
  "preço": 20.00





}
produtos = [dicionario1]
print(produtos)
# Out:
# [{'produto': 'leite em pó', 'preço': 20.0}]

# %%
dicionario2= {
    "produto": "esmalte",
    "PREÇO": 7.50
    }
produtos.append(dicionario2)
print(produtos)
# Out:
# [{'produto': 'leite em pó', 'preço': 20.0}, {'produto': 'esmalte', 'PREÇO': 7.5}]

# %%
dicionario1["preço"]= 15.00
print(produtos)
# Out:
# [{'produto': 'leite em pó', 'preço': 15.0}, {'produto': 'esmalte', 'PREÇO': 7.5}]

# %%
tupla = [("virgínia", 29), ("carlinhos", 33), ("maria", 18), ("pedro", 23)]

nomevelho= ""
idadevelha= 0

if tupla[0][1]> idadevelha:
  idadevelha= tupla[0][1]
  nomevelho= tupla[0][0]
  if tupla[1][1]> idadevelha:
    idadevelha= tupla[1][1]
    nomevelho= tupla [1][0]
    if tupla[2][1]> idadevelha:
      idadevelha= tupla [2][1]
      nomevelho= tupla [2][0]
      if tupla[3][1]> idadevelha:
        idadevelha= tupla [3][1]
        nomevelho= tupla [3][0]

media= tupla[0][1]+tupla[1][1]+tupla[2][1]+tupla[3][1]
media= media/len(tupla)

print("a pessoa mais velha é", nomevelho, "com", idadevelha, "anos de idade")
print("a media é de ", media)
# Out:
# a pessoa mais velha é carlinhos com 33 anos de idade
# a media é de  25.75

# %% [markdown]
# # Exercício de malipulação de string

# %%
# 1 - Use o método len para imprimir o comprimento da string.
x = "Hello World"
print(    )

# %%
# 2 - Obtenha o primeiro caractere da string txt.
txt = "Hello World"
x = txt[0]
print(x)
# Out:
# H

# %%
# 3 - Obtenha os caracteres do índice 2 ao índice 4 ( llo).
txt = "Hello World"
x = txt[2:5:]
print(x)
# Out:
# llo

# %%
# 4 - Converta o valor de txt para maiúsculas.
txt = "Hello World"
txt =txt.upper()
print(txt)
# Out:
# HELLO WORLD

# %%
# 5 - Conte quantas vezes aparece a palavra "de" na string abaixo
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"

# %%
# 6 - Separe a frase abaixo toda vez que encontrar um vírgula
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"

# %%
#7 - Peça ao usuário uma frase e substitua todas as ocorrências de espaço por “#”.

# %%
# 8 - Faça um programa que retorne True se duas strings lidas do teclado são palíndromas mútuas, ou seja, se uma é igual à outra quando lida de traz para frente ou False, se não forem.
# Por exemplo: amor e roma

# %%
# 9- Faça um programa que leia o nome do usuário e mostre o nome de traz para frente, utilizando somente letras maiúsculas.

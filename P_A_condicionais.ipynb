# %% [markdown]
# <a href="https://colab.research.google.com/github/juliaaparecida120/PA_2025/blob/main/P_A_condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tipos de condicionais
# condicionais simples: possui apenas duas possibilidades (true ou false)

# %%
nota1 = float(input("nota 1: "))
nota2 = float(input("nota 2: "))
nota3 = float(input("nota 3: "))

media= (nota1+nota2+nota53)/3
print(media)
# Out:
# nota 1: 8
# nota 2: 8
# nota 3: 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-60258b8695b9> in <cell line: 0>()
#       3 nota3 = float(input("nota 3: "))
#       4
# ----> 5 media= (nota1+nota2+nota53)/3
#       6 print(media)
#
# NameError: name 'nota53' is not defined

# %%
if(media>=7):
  print("voce foi aprovado")
else:
  print("voce foi reprovado")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f32d9b7e91cd> in <cell line: 0>()
# ----> 1 if(media>=7):
#       2   print("voce foi aprovado")
#       3 else:
#       4   print("voce foi reprovado")
#
# NameError: name 'media' is not defined

# %%
nota = float(input("digite a primeira nota: "))
if (nota>=0 and nota<=10):
  print("nota 1 computada")
  nota1= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")

nota = float(input("digite a segunda nota: "))
if (nota>=0 and nota<=10):
  print("nota 2 computada")
  nota2= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")


nota = float(input("digite a terceira nota: "))
if (nota>=0 and nota<=10):
  print("nota 3 computada")
  nota3= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")


media= (nota1+nota2+nota3)/3
print(media)
# Out:
# digite a primeira nota: 7
# nota 1 computada
# digite a segunda nota: 8
# nota 2 computada
# digite a terceira nota: 9
# nota 3 computada
# 8.0

# %%
if (media>= 7):
  print(" voce foi aprovado.")
else:
  print("voce foi reprovado.")
# Out:
#  voce foi aprovado.

# %% [markdown]
# #condicional composto
# condicional compostpo: possui mais de duas possibilidades

# %%
nota = float(input("digite a primeira nota: "))
if (nota>=0 and nota<=10):
  print("nota 1 computada")
  nota1= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")

nota = float(input("digite a segunda nota: "))
if (nota>=0 and nota<=10):
  print("nota 2 computada")
  nota2= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")


nota = float(input("digite a terceira nota: "))
if (nota>=0 and nota<=10):
  print("nota 3 computada")
  nota3= nota
else:
  print("essa nota nao foi registrada pois nao estava entra 0 e 10")
  print("execute novamente")
# Out:
# digite a primeira nota: 4
# nota 1 computada
# digite a segunda nota: 5
# nota 2 computada
# digite a terceira nota: 6
# nota 3 computada

# %%
if (media <5):
  print("sua mençao final é i")
elif (media >=5 and media <6.5):
  print("sua mençao final é r")
elif (media >=6.5 and media <8.5):
  print("sua mençao final é b")
else:
  print("sua mençao final é mb")
# Out:
# sua mençao final é b

# %% [markdown]
# #condicional aninhado
# quando o segundo if só é executado quando o primeiro for TRUE

# %%
usuariocerto = "juliarudel"
senhacerta = "julia"

usuario= input("digite o nome de usuario: ")
if (usuario== usuariocerto):
senha= input("digite sua senha: ")
  if (senha== senhacerta)
else:
  print("Senha incorreta.")
else:
  print("Usuário incorreto.")
# Out:
#   File "<ipython-input-55-de98131f43c3>", line 6
#     senha= input("digite sua senha: ")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %% [markdown]
# #lista de exercicios

# %% [markdown]
# Faça um programa que solicite ao usuário três valores (lados de um triangulo), verifique se é um triangulo e informe se ele é isóceles, equilatero ou escaleno.

# %%
lado1 = float(input("digite o lado 1 do triangulo: "))
lado2 = float(input("digite o lado 2 do triangulo: "))
lado3 = float(input("digite o lado 3 do triangulo: "))

triangulo = (lado1 + lado2 > lado3) and (lado1 + lado3 > lado2) and (lado2 + lado3 > lado1)
if (triangulo == True):
  print(" é qual tipo de triangulo? ")
  if(lado1 == lado2 == lado3):
   print("triangulo equilátero.")
  elif (lado1 != lado2 and lado1 != lado3):
    print("escaleno")
# Out:
# digite o lado 1 do triangulo: 7
# digite o lado 2 do triangulo: 8
# digite o lado 3 do triangulo: 9
#  é qual tipo de triangulo?
# escaleno

# %% [markdown]
# 2- Peça para o usuário digitar um valor informe se ele é par ou impar

# %%
num = int(input("digite um valor: "))

if(num % 2 ==0):
 print("é um numero par")
else:
  print("é um numero impar")
# Out:
# digite um valor: 2
# é um numero par

# %% [markdown]
# 3-Faça um programa que solicite peso e altura, informe seu IMC. Ao final informe se ele está, abaixo do peso,peso ideal ou acima do peso. fórmula do IMC: (peso/altura^2), siga a tabela abaixo:

# %%
peso = float(input("digite seu peso: "))
altura = float(input("digite sua altura: "))

imc = peso / altura ** 2

if(imc < 18.5):
  print("abaixo do peso")
elif(imc >= 18.5 and imc <= 24.9):
 print("peso normal")
elif(imc >= 25 and imc <= 29.9):
 print("sobre peso")
elif(imc >= 30 and imc <= 34.9):
  print("obesidade grua 1")
elif(imc >= 35 and imc <= 39.9):
  print("obesidade grau 2")
elif(imc >= 40):
  print("obesidade grau 3")
# Out:
# digite seu peso: 88
# digite sua altura: 1.55
# obesidade grau 2

# %% [markdown]
# 4. Caixa Eletrônico com Login e Operações Bancárias
#
# Crie um programa que simule um caixa eletrônico. O programa deve:
#
# Solicitar ao usuário nome de usuário e senha para acessar a conta bancária (use valores fictícios para usuário e senha, por exemplo, "cliente" e "1234").

# %%
limite = 3000
saldo = 5000

usuariocerto = "juliarudel"
senhacerta = "0507"

usuario= str(input("digite o nome de usuario: "))
if (usuario== usuariocerto):
 senha= str(input("digite sua senha: "))
 print("usuario logado")
if (senha== senhacerta):
  print("usuario logado")
opçao = input ("qual operaçao deseja fazer ?/nDigite 1 para sacar .\nDigite 2 para depositar .\nDigite 3 para ver saldo na conta.")
# Out:
# digite o nome de usuario: juliarudel
# digite sua senha: 0507
# usuario logado
# usuario logado
# qual operaçao deseja fazer ?/nDigite 1 para sacar .
# Digite 2 para depositar .
# Digite 3 para ver saldo na conta.3

# %%
# Dados fictícios para login
usuario_correto = "cliente"
senha_correta = "1234"

# Solicita os dados do usuário
usuario = input("Digite o nome de usuário: ")
senha = input("Digite a senha: ")

# Verifica as credenciais
if usuario == usuario_correto and senha == senha_correta:
    print("Acesso permitido. Bem-vindo ao caixa eletrônico!")

elif usuario != usuario_correto or senha != senha_correta:
    print("Usuário ou senha incorretos. Tente novamente.")
else:
    print("Erro inesperado. Tente novamente mais tarde.")

# %%
peso = float(input("Informe o peso do lutador em kg: "))

if peso > 90.72:
    categoria = "Pesado"
elif peso > 79.38:
    categoria = "Cruzador"
elif peso > 76.2:
    categoria = "Meio-Pesado"
elif peso > 73.03:
    categoria = "Super Médio"
elif peso > 69.85:
    categoria = "Médio"
elif peso > 66.68:
    categoria = "Super Meio-Médio"
elif peso > 63.5:
    categoria = "Meio-Médio"
elif peso > 61.23:
    categoria = "Super Leve"
elif peso > 58.97:
    categoria = "Leve"
elif peso > 57.15:
    categoria = "Super Pena"
elif peso > 55.34:
    categoria = "Pena"
elif peso > 53.52:
    categoria = "Super Galo"
elif peso > 51.71:
    categoria = "Galo"
elif peso > 50.35:
    categoria = "Super Mosca"
elif peso > 48.99:
    categoria = "Mosca"
elif peso > 47.63:
    categoria = "Mosca Ligeiro"
elif peso > 46.27:
    categoria = "Palha"
else:
    categoria = "Palha Ligeiro"

print(f"A categoria do lutador é: {categoria}")

# %%
salario = float(input("Digite o seu salário: R$ "))

if salario <= 1903.98:
    print("Isento de imposto de renda.")
elif salario <= 2826.65:
    imposto = salario * 0.075
    print(f"Imposto de Renda: R$ {imposto:.2f} (7,5%)")
elif salario <= 3751.05:
    imposto = salario * 0.15
    print(f"Imposto de Renda: R$ {imposto:.2f} (15%)")
elif salario <= 4664.68:
    imposto = salario * 0.225
    print(f"Imposto de Renda: R$ {imposto:.2f} (22,5%)")
else:
    imposto = salario * 0.275
    print(f"Imposto de Renda: R$ {imposto:.2f} (27,5%)")

# %%
# Solicita a altura e a idade do usuário
altura = float(input("Digite sua altura em metros (ex: 1.75): "))
idade = int(input("Digite sua idade: "))

# Verifica se o usuário pode competir
if altura >= 1.75 and idade >= 18:
    print("Você pode competir no campeonato de vôlei.")
elif altura < 1.75 and idade < 18:
    print("Você não pode competir: sua altura e sua idade estão abaixo do permitido.")
elif altura < 1.75:
    print("Você não pode competir: sua altura está abaixo do permitido.")
else:
    print("Você não pode competir: sua idade está abaixo do permitido.")

# %%
# Define o valor por 100 km com base no peso
if peso <= 2:
    preco_por_100km = 5
elif peso <= 5:
    preco_por_100km = 8
else:
    preco

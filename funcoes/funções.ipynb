# %% [markdown]
# <a href="https://colab.research.google.com/github/juliaaparecida120/PA_2025/blob/main/funcoes/fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# estou definindo as funções **negrito**

# %%
def soma (x,y):
  total= x+y
  print(soma)

def diminuir(x,y):
  subtrai = x-y
  print(subtrai)

# %% [markdown]
# agora vou chamar a função

# %%
valor1 = float(input("digite o primeiro valor: "))
valor2 = float(input("digite o segundo valor: "))
soma(valor1,valor2)
diminuir(valor1,valor2)
# Out:
# digite o primeiro valor: 8
# digite o segundo valor: 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-524187560.py in <cell line: 0>()
#       1 valor1 = float(input("digite o primeiro valor: "))
#       2 valor2 = float(input("digite o segundo valor: "))
# ----> 3 soma(valor1,valor2)
#       4 diminuir(valor1,valor2)
#
# NameError: name 'soma' is not defined

# %% [markdown]
# # estou definindo as funções com **retornop**

# %%
def mult (x,y):
  total = x*y
  return total
def divisão (x,y):
  total=x/y
  return total

# %% [markdown]
# # chamando uma função com retorno

# %%
valor1 = float(input("digite o primeiro valor: "))
valor2 = float(input("digite o segundo valor: "))
multiplicação = mult(valor1, valor2)
divisão = divisão(valor1,valor2)

print("a multiplicação é", multiplicação)
print("o resultado da divisão é", divisão)
# Out:
# digite o primeiro valor: 10
# digite o segundo valor: 2
# a multiplicação é 20.0
# o resultado da divisão é 5.0

# %% [markdown]
# # funções sem retorno e sem parâmetro

# %%
def saudacao():
   print("Olá! Seja bem-vindo(a) ao curso de Python!")

# %%
saudacao()
# Out:
# Olá! Seja bem-vindo(a) ao curso de Python!

# %%
from datetime import datetime

def mostrar_horario():
    agora = datetime.now()
    print(f"Horário atual: {agora.strftime('%H:%M:%S')}")

# %%
mostrar_horario()
# Out:
# Horário atual: 18:23:15

# %% [markdown]
# # definido funções com parametro e sem retorno

# %%
def apresentar(nome):
  print(f"Olá, {nome}! Prazer em te conhecer.")

# %%
nome = input("digite sem nome: ")
apresentar (nome)
# Out:
# digite sem nome: julia
# Olá, julia! Prazer em te conhecer.

# %%
def verificar_paridade(numero):
  if numero % 2 == 0:
    print(f"o numero {numero} é par")
  else:
      print(f"o numero {numero} é impar")

verificar_paridade (7)
verificar_paridade (12)
# Out:
# o numero 7 é impar
# o numero 12 é par

# %%
def boas_vindas(nome,curso):
  print(f"ola, {nome}! seja bem vindo(a) ao {curso}!")

boas_vindas ("cintia", "programação em python")
# Out:
# ola, cintia! seja bem vindo(a) ao programação em python!

# %%
def somadenotas():
  nota1= float(input("digite a primeira nota: "))
  nota2= float(input("digete a segunda nota: "))
  nota3= float(input("digite a terceira nota: "))
  total= nota1+nota2+nota3
  return total

somatresnotas= somadenotas()

def medianota():
  media = somatresnotas/3
  return media

mediatresnotas= medianota()

print("a soma das notas é de", somatresnotas)
print("a media das notas é de", mediatresnotas)
# Out:
# digite a primeira nota: 50
# digete a segunda nota: 7
# digite a terceira nota: 8
# a soma das notas é de 65.0
# a media das notas é de 21.666666666666668

# %% [markdown]
# # teste

# %% [markdown]
# **exercicios**

# %% [markdown]
# Função com Parâmetro e com ***Retorno***

# %%
peso = float(input("digite seu peso em (kg): "))
altura = float(input("digite sua latura em (m): "))

def imc(peso, altura):
  calc= peso/(altura ** 2)
  return calc

resultado= imc(peso, altura)
print(f"Seu IMC é de {resultado:.2f}")
# Out:
# digite seu peso em (kg): 56
# digite sua latura em (m): 1.66
# Seu IMC é de 20.32

# %% [markdown]
# # **exercicios**

# %% [markdown]
# 1) Mensagem de Boas-vindas

# %%
def saudação():
  return" tenha um otimo dia !!"

# %%
print(saudação())
# Out:
#  tenha um otimo dia !!

# %% [markdown]
# # 2-Conversor de **Temperatura**

# %% [markdown]
# Crie uma função chamada celsius_para_fahrenheit que recebe uma temperatura em Celsius (c
# ) e retorna a temperatura equivalente em Fahrenheit (f
# ).

# %%
def conversao():
  return cel * 1.8 + 32

celsius= float(input("Digite uma temperatura em graus Celsius: "))
Faren= conversao()
# Out:
# Digite uma temperatura em graus Celsius: 18

# %%
print(f"A temperatura em Farenheits é de: {Faren:.2f}")
# Out:
# A temperatura em Farenheits é de: 64.40

# %% [markdown]
# ## 3-**mensagem** **personalizada**

# %% [markdown]
# Crie uma função chamada boas_vindas_personalizada que recebe um parâmetro nome (string) e imprime uma mensagem de boas-vindas usando esse nome (Ex: "Olá, [Nome]! Seja bem-vindo.").
#
# Esta função recebe um parâmetro, mas não precisa de um retorno, pois sua finalidade é apenas a exibição na tela.

# %%
def boas_vindas_pers(nome):
  print(f"Seja Bem Vindo {nome}!!")

nome= str(input("Digite seu Nome: "))
# Out:
# Digite seu Nome: julia

# %%
boas_vindas_pers(nome)
# Out:
# Seja Bem Vindo julia!!

# %% [markdown]
# 4- quadrado e **cubo**

# %% [markdown]
# Crie uma função chamada calcular_potencias que recebe um número n e retorna o quadrado e o cubo desse número em uma tupla.
#
# A função deve retornar dois valores. Lembre-se que em Python, você pode retornar múltiplos valores, que são automaticamente empacotados em uma tupla.

# %%
def calcular_potencias(num):
  quad= num ** 2
  cub= num ** 3
  return quad, cub

num= float(input("Digite um número: "))
resultado= calcular_potencias(num)
tupla= (resultado)
# Out:
# Digite um número: 6

# %%
print(tupla)
# Out:
# (36.0, 216.0)

# %% [markdown]
# # 5-contagem regressiva

# %% [markdown]
# Crie uma função chamada contagem_regressiva que recebe um número inteiro inicio e imprime todos os números de inicio até 1.
#
#  Use um laço de repetição (for ou while) para iterar e imprimir os números sequencialmente. Não é necessário retornar nada.

# %%
def contagem (num):
  for i in range(num, 0, -1):
    print(i)


x = int(input('Qual é seu número?: '))
regresso = contagem(x)
# Out:
# Qual é seu número?: 7
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # 6- **Cálculo** de Desconto

# %% [markdown]
# Desenvolva uma função chamada calcular_desconto que aceita valor_original e percentual_desconto como parâmetros e retorna o valor final após aplicar o desconto.
#
# $$
# \text{Valor Final} = \text{Valor Original} \times (1 - \frac{\text{Percentual Desconto}}{100})
# $$
#
#  Para calcular o percentual corretamente, divida o percentual_desconto por 100 antes de subtrair de 1.

# %%
def calcular_descontos (valor, percentual):
  total= valor * (1- percentual /100)
  return total

valor= float(input("digite o valor do produto: "))
percentual= float(input("digiteo valor do desconto: "))
final= calcular_descontos(valor, percentual)
# Out:
# digite o valor do produto: 100
# digiteo valor do desconto: 6

# %%
print(f"o valor final é de {final:.2f}")
# Out:
# o valor final é de 94.00

# %% [markdown]
# # 7- Maior e **Menor**

# %% [markdown]
# Crie uma função chamada encontrar_extremos que recebe uma lista de números e retorna o maior e o menor número da lista.
#
#  Você pode explorar as funções nativas do Python max() e min() para uma solução concisa, ou implementar a lógica de comparação manualmente.

# %%
def extremos():
  maior= max(lista)
  menor= min(lista)
  return maior, menor

lista= [10,2,30,7.5,-20]
final= extremos()

# %%
print(final)
# Out:
# (30, -20)

# %% [markdown]
# # 8- Calculadora **Simples**

# %% [markdown]
# Crie uma função chamada calculadora que recebe dois números (a e b) e uma operacao (string: 'soma', 'subtracao', 'multiplicacao', 'divisao') e retorna o resultado da operação.
#
#  Use estruturas condicionais (if/elif/else) para determinar qual cálculo realizar e adicione uma verificação para evitar divisão por zero.

# %%
def calculadora(a, b, operacao):
    if operacao == 'soma':
        return a + b
    elif operacao == 'subtração':
        return a - b
    elif operacao == 'multiplicação':
        return a * b
    elif operacao == 'divisão':
        if a == 0:
            print("Divisão não realizada")
        elif b == 0:
          print("Divisão não realizada")
        else:
            return a / b
    else:
        print("Operação inválida.")

operacao= str(input("Digite a operação desejada: "))
a= float(input("Digite um número: "))
b= float(input("Digite um número: "))
resultado= calculadora(a, b, operacao)
# Out:
# Digite a operação desejada: soma
# Digite um número: 8
# Digite um número: 2

# %%
print (f"o resultado é de {resultado:.2f}")
# Out:
# o resultado é de 10.00

# %% [markdown]
# # 9-Mensagem **Automática**

# %% [markdown]
# Crie uma função chamada enviar_email que recebe destinatario e assunto, e opcionalmente um corpo da mensagem. Se o corpo não for fornecido, use um texto padrão como "Este é um email automático."
#
#  Defina o parâmetro corpo com um valor padrão (default value) na assinatura da função para torná-lo opcional.

# %%
def email(destinatario, assunto, corpo):
  print(f"enviando email para {destinatario}")
  print(f"assunto: {assunto}")
  print(f"mensagem: {corpo}")

destinatario= str(input("digiteo destinatario: "))
assunto= str(input("digite o assunto: "))

escolha= str (input("\nDigite sim para escrever alguma coisa no corpo \nDigite nao se nao quiser "))

if escolha == "sim":
  corpo= str(input("Digite o que deseja falar: "))
else:
  corpo= "este é um email automatico"

email(destinatario, assunto, corpo)
# Out:
# digiteo destinatario: vitoria
# digite o assunto: chata
#
# Digite sim para escrever alguma coisa no corpo
# Digite nao se nao quiser sim
# Digite o que deseja falar: kakak
# enviando email para vitoria
# assunto: chata
# mensagem: kakak

# %% [markdown]
# # 10-Sistema de **Notas**

# %% [markdown]
# Desenvolva uma função chamada avaliar_aluno que recebe uma nota (número) e retorna uma string indicando a situação do aluno: "Aprovado" (nota $\ge 7$), "Recuperação" ($\ge 5$ e $< 7$) ou "Reprovado" ($< 5$).
#
#  Lembre-se de usar operadores lógicos como and para definir os intervalos de notas de forma clara.

# %%
def avaliar(nota):
  if nota >= 7:
    return "voce foi aprovado"
  elif nota >= 5 and nota <7:
    return "voce esta de recuperação"
  else:
    print("nota inválida")

nota= float(input("digite sua nota: "))

avaliar(nota)
# Out:
# digite sua nota: 3
# nota inválida
